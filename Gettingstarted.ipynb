# %%
import os 
from dotenv import load_dotenv
load_dotenv()

os.environ['OPENAI_API_KEY']=os.getenv("OPENAI_API_KEY")
os.environ["LANGCHAIN_API_KEY"]=os.getenv("LANGCHAIN_API_KEY")
os.environ["LANGCHAIN_TRACING_V2"]="true"
os.environ["LANGCHAIN_PROJECT"]=os.getenv("LANGCHAIN_PROJECT")

# %%
from langchain_openai import ChatOpenAI
llm=ChatOpenAI(model="gpt-4o")
print(llm)
# Out:
# profile={'max_input_tokens': 128000, 'max_output_tokens': 16384, 'text_inputs': True, 'image_inputs': True, 'audio_inputs': False, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True, 'structured_output': True, 'image_url_inputs': True, 'pdf_inputs': True, 'pdf_tool_message': True, 'image_tool_message': True, 'tool_choice': True} client=<openai.resources.chat.completions.completions.Completions object at 0x000001FFB0348D30> async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x000001FFB30FF730> root_client=<openai.OpenAI object at 0x000001FFB034BCA0> root_async_client=<openai.AsyncOpenAI object at 0x000001FFB30FF6A0> model_name='gpt-4o' model_kwargs={} openai_api_key=SecretStr('**********') stream_usage=True

# %%
result=llm.invoke("Best Ai for today?")
print(result)
# Out:
# content='As of my last training data in October 2023, there are several notable AI systems, each excelling in different domains:\n\n1. **OpenAI\'s GPT-4**: This is one of the most advanced language models for generating human-like text, powering applications in content creation, customer support, and more.\n\n2. **DeepMind’s AlphaFold**: Known for its breakthrough in solving the protein folding problem, it significantly impacts bioinformatics and drug discovery.\n\n3. **Google\'s Bard / PaLM**: An AI focused on natural language understanding and generation, used for tasks like translation, summarization, and more.\n\n4. **Anthropic’s Claude**: Known for its focus on aligning AI with human values, it\'s an alternative approach to safe and ethical AI development.\n\n5. **Meta’s LLaMA**: A suite of large language models designed to improve accessibility and performance in research applications.\n\n6. **Midjourney and DALL-E**: Leading image generation AIs that enable the creation of stunning visuals from textual descriptions.\n\nThe "best" AI depends on your specific needs—whether you\'re looking for capabilities in natural language processing, image synthesis, or scientific research. Always consider aspects like ethical use, privacy, and alignment with your goals when choosing an AI system.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 260, 'prompt_tokens': 12, 'total_tokens': 272, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_cd34b9b50e', 'id': 'chatcmpl-D9pJXeWaeRbhxhyar3ROZuIV77DXc', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019c65ce-b3c2-7342-b9a6-15fa1653f239-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 12, 'output_tokens': 260, 'total_tokens': 272, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %% [markdown]
# Chatprompt template

# %%
from langchain_core.prompts import ChatPromptTemplate
prompt=ChatPromptTemplate.from_messages(
    [
        ("system","Im a AI engineer. give me answer for my question"),
        ("user","{input}")
    ]
)
prompt
# Out:
# ChatPromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Im a AI engineer. give me answer for my question'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, template='{input}'), additional_kwargs={})])

# %%
## chain 
chain=prompt|llm

response=chain.invoke({"input":"Can you tell me about langchain?"})
print(response)
# Out:
# content="LangChain is a framework designed for developing applications powered by large language models (LLMs). It facilitates the creation of a wide range of applications, from chatbots and question-answering systems to more complex use cases involving document analysis and summarization. LangChain's primary goal is to make it easier for developers to integrate LLMs into applications efficiently while providing tools to manage prompts, handle conversation state management, and interface with various data sources.\n\nKey components of LangChain include:\n\n1. **Prompt Templates**: Allows for the creation and management of dynamic and reusable prompts, making it easier to experiment with different prompts without having to rewrite code.\n\n2. **Chains**: Combines multiple LLM calls and other functions into a single coherent workflow, enabling complex interactions and multi-step processes.\n\n3. **Agents**: These are intelligent entities that can interact with the language model in a multi-turn conversation, keeping track of the context to maintain coherence.\n\n4. **Memory**: Provides context and state management across interactions, allowing applications to maintain continuity in conversations.\n\n5. **Knowledge Bases**: Integrates external data sources or databases, enabling applications to augment LLMs with domain-specific knowledge.\n\n6. **Tools and Integrations**: Offers integration with various APIs, databases, and knowledge graphs to extend the capabilities of the language models.\n\nLangChain is particularly useful for developers looking to leverage the full potential of language models without having to handle the intricacies of prompt engineering and state management manually. It is an open-source project, and its modular structure allows developers to adapt and extend it based on their specific application needs." additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 323, 'prompt_tokens': 30, 'total_tokens': 353, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_cd34b9b50e', 'id': 'chatcmpl-D9pJhzb8R3ypS6r222qjBzy0YHoGV', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019c65ce-dbc0-7982-af63-52999aed0162-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 30, 'output_tokens': 323, 'total_tokens': 353, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
from langchain_core.output_parsers import StrOutputParser
output_parser=StrOutputParser()
chain=prompt|llm|output_parser

response=chain.invoke({"input":"Can you tell me about Langchain?"})
print(response)
# Out:
# Langchain is an open-source framework designed to facilitate the development of applications using large language models (LLMs). It provides a set of tools and components to simplify the process of building, deploying, and maintaining applications that leverage the power of language models. Langchain is often used for creating sophisticated natural language processing (NLP) applications such as chatbots, question-answering systems, and more.
#
# Key features of Langchain include:
#
# 1. **Modularity**: Langchain offers a modular architecture, making it easy to integrate various components and functionalities like data connectors, LLMs, and prompt management.
#
# 2. **Prompt Engineering**: Streamlines the creation and management of prompts to optimize the interaction with language models, allowing developers to iterate and refine the way inputs are presented to the model.
#
# 3. **Integration**: Langchain can easily connect with various data sources and APIs, allowing developers to build applications that can pull and push data across different platforms seamlessly.
#
# 4. **Ease of Use**: By abstracting complex processes, Langchain provides a user-friendly interface for developers to work with language models without delving into the intricacies of model optimization or extensive infrastructure management.
#
# 5. **Scalability**: Designed to support scalable applications, Langchain can handle growing data demands and user loads efficiently.
#
# Langchain is particularly popular among developers and researchers who want to build applications that require understanding and generating human-like text, leveraging the advanced capabilities of language models like GPT (Generative Pre-trained Transformer) and others.
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
